# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')
# %matplotlib inline

import pyoz as oz

# %%
lj_unary = oz.System()
lj_unary.set_interaction(0, 0, oz.lennard_jones(lj_unary.r, eps=1.0, sig=2.0))
r = lj_unary.r
U_r = lj_unary.U_r

# %%
plt.plot(r, U_r[0, 0])
plt.xlabel('r')
plt.ylabel('U(r)')
plt.xlim(0, 10)
plt.ylim(-1.5, 1)
# Out:
# (-1.5, 1)

# %%
g_r, c_r, e_r, S_k = lj_unary.solve(rhos=0.1, closure_name='hnc')
# Out:
# [INFO][2016-10-03 17:02:23,146] Converged in 2.04s after 600 iterations

# %%
plt.plot(r, g_r[0, 0])
plt.xlabel('r')
plt.ylabel('g(r)')
plt.xlim(0, 10)
# Out:
# (0, 10)
